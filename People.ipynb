# %%
import pandas as pd

# %%
df = pd.read_csv("People.csv")

# %%
df
# Out:
#          Index          User Id First Name Last Name     Sex  \
# 0           23  69de9efF61C73FB    Whitney    Farmer    Male
# 1         1036  B05D482b6e219e7    Whitney    Mccann    Male
# 2         1316  9a7ADFfeB2Ab87a    Whitney   Hopkins    Male
# 3         1745  B649beAc37fD267    Whitney    Zavala    Male
# 4         5624  E7EeF7Db4a5EbcD    Whitney     Barry    Male
# ...        ...              ...        ...       ...     ...
# 999995  990910  f2B0e87FCAdae64     Sheena      Barr  Female
# 999996  992418  28EE2173eba1A1E     Sheena   Elliott  Female
# 999997  998371  3E4175FeFCd002D     Sheena     Boyle  Female
# 999998  998874  0eAb6bEc3AE82cf     Sheena      Haas  Female
# 999999  999126  Df1eee2433446F3     Sheena    Miller  Female
#
#                                Email                  Phone  \
# 0              gloverjim@example.com     627-745-0313x06256
# 1         theodoreharris@example.net             7128156344
# ...
